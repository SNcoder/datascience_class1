# %%
q1

# %%
exception are raised when programme is syntaticaly is corret but 
code resulted in an error.this error does not stop the excecutation of programme but it change the flow of code.
syntax error:- a syntax error is an error which name suugest this type of error occur when we run a programme.when we wrongly write a code so we got an syntax error.
exception error:- exception error also occur in run time.this error generated by executation time here code has no error it given by interpreter.

# %%
q2

# %%
when the exception is not handled it will cause the programme to terminate with an error message. Error include the information about which  type of exception is occured and location of programm where the exception is occured.

try:

    a=5
    a/0
except FileNotFoundError as e:
    print(e)

# %%
q3

# %%
in Python, you can catch and handle exceptions using the try...except statement. The basic syntax for this statement is:

python
Copy code
try:
except Exception as e:
    print(e)

def divide(x, y):
    try:
        result = x / y
    except ZeroDivisionError:
        print("Error: division by zero")
    except ValueError:
        print("Error: invalid input")
    else:
        print("Result:", result)

divide(10, 2)  
divide(10, 0)  
divide("10", "2")

# %%
q4

# %%
try:-try is used to handle the exception.satement which raised the exception are kept inside the try clause and  wrriten inside the try block. and except block catch the exception and handle exception.
else:-else clause is present after all except clause and it will excecuted only once when try block not raised any exception .
finally:-finally always exceuted after try except block . the final block always execute the normal termination of try block or try block terrminate due to exception.
raise:- raise satatement force to programmer to raised a specific type of exception.the sole argument in raise indicate the exception to be raised.
example
class negative_age(Exception):
    def __init__(self,message):
        self.message=message
def negativeage(age):
    if age<0:
        raise negative_age("age cannot be negative")
    else:
        print("age is valid")

try:
    age=int(input("enter thr age"))
    negative_age(age)

except negative_age as e:
    print("file is not found ",e)
else:
    print("try block executed suucessfully without any exception ")
finally:
    print("program is going to terminated")

# %%
q5

# %%
custom exception class is usser defined class which is created by developer for handling a specific error or handle a specific exception case.
why we need custom exception class..
when programme is not generate any type of error but at developer side it gave an error so we generate a cosutom class for handle specific error or exception case. 
# "example:"
def negativeage(age):
    if age<0:
        raise negative_age("age cannot be negative")
    else:
        print("age is valid")

try:
    age=int(input("enter thr age"))
    negative_age(age)

except negative_age as e:
    print("file is not found ",e)
else:
    print("try block executed suucessfully without any exception ")
finally:
    print("program is going to terminated")

# %%
q6
